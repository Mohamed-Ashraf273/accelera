# %%
from accelera.src.core.parallelizer import parallelizer

# %%
new_code = parallelizer.parallelize("test_loops.c")
# Out:
# Successfully formatted parallelized_test_loops.c with clang-format
