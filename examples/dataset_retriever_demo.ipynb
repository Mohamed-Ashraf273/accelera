# %%
from accelera.src.utils.dataset_retriever import retriever

# %%
print("Available datasets:", retriever.available_datasets())
# Out:
# Available datasets: ['customer_purchase_data', 'DailyDialog', 'student_exam_performance_dataset', 'job_salary_prediction_dataset', 'heart', 'student_placement_synthetic', 'Titanic-Dataset', 'Housing', 'TestReviews', 'Dataset_spine']

# %%
retriever.connect()

# %%
dataset = retriever.retrieve_dataset("Housing")
print(dataset)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VMtLcWDcigwkimpf-eWVMZ7zJMUf7wxs
# To: /home/mohamed-ashraf/.cache/accelera/Housing.csv
# 100%|██████████| 30.0k/30.0k [00:00<00:00, 387kB/s]
# /home/mohamed-ashraf/.cache/accelera/Housing.csv

# %%
retriever.close()
