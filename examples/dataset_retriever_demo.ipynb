# %%
from accelera.src.utils.dataset_retriever import retriever

# %%
print("Available datasets:", retriever.available_datasets())
# Out:
# Available datasets: ['diabetes_dataset', 'student_exam_performance_dataset', 'Dataset_spine', 'Housing', 'Titanic-Dataset', 'customer_purchase_data', 'heart_disease', 'DailyDialog', 'job_salary_prediction_dataset', 'TestReviews', 'heart', 'student_placement_synthetic']

# %%
retriever.connect()

# %%
dataset = retriever.retrieve_dataset(
    dataset_name="ds1",
)
print(dataset)
# Out:
# /home/mohamed-ashraf/.cache/accelera/ds1.csv

# %%
retriever.close()
